# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Arpit"
print(name)
# Out:
# Arpit

# %%
age = 18        # int
price = 99.99   # float
name = "Arpit"  # string
passed = True   # boolean

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Hello Arpit Malhan

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A+")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
else:
    print("Grade D")
# Out:
# Grade B

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("Even")
else:
    print("odd")
# Out:
# Even

# %%
number = int(input("Enter a number: "))
if number > 0:
    print("Positive")
elif number < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Positive

# %%
number = int(input("Enter a number: "))
if number % 3 == 0 and number % 5 == 0:
    print("Divisible by Both Numbers")
else:
    print("Not Divisible by Both Numbers")
# Out:
# Not Divisible by Both Numbers

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
height = float(input("Enter your height: "))
Favorite_Sport = input("Enter your favorite sport: ")

print("-----Personal Information-----")
print("Name:", name)
print("Age:", age)
print("Height (in cm):", height)
print("Favorite Sport:", Favorite_Sport)
# Out:
# -----Personal Information-----
# Name: Arpit Malhan
# Age: 18
# Height (in cm): 180.0
# Favorite Sport: Footballl
